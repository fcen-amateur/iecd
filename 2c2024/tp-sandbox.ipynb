# %%
import numpy as np

# %%
l = np.array([5,-2, 3, 2])

# %%
ranks = np.argsort(l)

# %%
np.array(l)[ranks]
# Out:
# array([-2,  2,  3,  5])

# %%
l, ranks + 1
# Out:
# (array([ 5, -2,  3,  2]), array([2, 4, 3, 1]))

# %%
4, 1, 3, 2
# Out:
# (4, 1, 3, 2)

# %%
np.argsort(ranks) + 1
# Out:
# array([4, 1, 3, 2])

# %%
X = np.random.normal(size = 100)
X = np.array([5,2,3,4,1])
ranks = np.argsort(X)
all(np.argsort(np.argsort(np.argsort(X))) == np.argsort(X))
# Out:
# True

# %%
X
# Out:
# array([5, 2, 3, 4, 1])

# %%
X[ranks]
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.argsort(ranks)
# Out:
# array([4, 1, 2, 3, 0])
